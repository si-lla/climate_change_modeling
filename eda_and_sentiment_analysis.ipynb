# %%
# Step 1: Import required libraries
import pandas as pd

# Step 2: Load the dataset
df = pd.read_csv('../data/<your_filename>.csv')  # Replace <your_filename> with actual file name

# Step 3: Preview the dataset
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import pandas as pd
#       4 # Step 2: Load the dataset
# ----> 5 df = pd.read_csv('../data/<your_filename>.csv')  # Replace <your_filename> with actual file name
#       7 # Step 3: Preview the dataset
#       8 df.head()
#
# ...

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('../data/climate_nasa.csv')

# Preview the first few rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       3 # Load the dataset
# ----> 4 df = pd.read_csv('../data/climate_nasa.csv')
#       6 # Preview the first few rows
#       7 df.head()
#
# ...

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('../data/climate_nasa')

# Preview the first few rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       3 # Load the dataset
# ----> 4 df = pd.read_csv('../data/climate_nasa')
#       6 # Preview the first few rows
#       7 df.head()
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\user\\OneDrive\\Desktop\\climate_change_modeling'

# %%
import pandas as pd

df = pd.read_csv('data/climate_nasa.csv')  # ✅ This path is correct based on your structure
df.head()  # 👀 Preview first 5 rows
# Out:
#                        date  likesCount  \
# 0  2022-09-07T17:12:32.000Z           2
# 1  2022-09-08T14:51:13.000Z           0
# 2  2022-09-07T17:19:41.000Z           1
# 3  2022-09-08T00:51:30.000Z           4
# 4  2022-09-07T19:06:20.000Z          16
#
#                                          profileName  commentsCount  \
# 0  4dca617d86b3fdce80ba7e81fb16e048c9cd9798cdfd6d...            NaN
# 1  518ab97f2d115ba5b6f03b2fba2ef2b120540c9681288b...            NaN
# 2  d82e8e24eb633fd625b0aef9b3cb625cfb044ceb8483e1...            3.0
# 3  37a509fa0b5177a2233c7e2d0e2b2d6916695fa9fba3f2...            NaN
# 4  e54fbbd42a729af9d04d9a5cc1f9bbfe8081a31c219ecb...           26.0
#
#                                                 text
# 0  Neat comparison I have not heard it before.\n ...
# 1  An excellent way to visualise the invisible! T...
# 2  Does the CO2/ghg in the troposphere affect the...
# 3  excellent post! I defo feel the difference - o...
# ...

# %%
# Shape of the dataset
df.shape

# Column names
df.columns

# Data types and null values
df.info()

# Count missing values per column
df.isnull().sum()

# Summary statistics for numeric columns
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           522 non-null    object
#  1   likesCount     522 non-null    int64
#  2   profileName    522 non-null    object
#  3   commentsCount  244 non-null    float64
#  4   text           504 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 20.5+ KB
#        likesCount  commentsCount
# count  522.000000     244.000000
# mean     4.720307       8.696721
# std     12.053556      12.266176
# min      0.000000       1.000000
# 25%      0.000000       2.000000
# 50%      1.000000       5.000000
# 75%      4.000000      10.000000
# max    126.000000      93.000000

# %%
# !pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# ...
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 624.3/624.3 kB 4.7 MB/s eta 0:00:00
# ...

# %%
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'textblob'

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'textblob'

# %%
# !pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'textblob'

# %%
pip install textblob
# Out:
# ...
#   Using cached textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# ...
# Using cached textblob-0.19.0-py3-none-any.whl (624 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from textblob import TextBlob

# %%
# Apply TextBlob polarity to each comment
df['polarity'] = df['Text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
# ...

# %%
df.columns
# Out:
# Index(['date', 'likesCount', 'profileName', 'commentsCount', 'text'], dtype='object')

# %%
df['polarity'] = df['text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='sentiment', data=df, palette='Set2')
plt.title("Sentiment Distribution of NASA Climate Comments")
plt.xlabel("Sentiment")
plt.ylabel("Number of Comments")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 4 sns.countplot(x='sentiment', data=df, palette='Set2')
#       5 plt.title("Sentiment Distribution of NASA Climate Comments")
#       6 plt.xlabel("Sentiment")
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
# ...

# %%
df.columns
# Out:
# Index(['date', 'likesCount', 'profileName', 'commentsCount', 'text',
#        'polarity'],
#       dtype='object')

# %%
# Function to label sentiment
def get_sentiment(score):
    if score > 0:
        return 'Positive'
    elif score < 0:
        return 'Negative'
    else:
        return 'Neutral'

# Apply the function
df['sentiment'] = df['polarity'].apply(get_sentiment)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='sentiment', data=df, palette='Set2')
plt.title("Sentiment Distribution of NASA Climate Comments")
plt.xlabel("Sentiment")
plt.ylabel("Number of Comments")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6228\603459528.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sentiment', data=df, palette='Set2')

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
df['year'] = df['date'].dt.year

# %%
# Group by year and sentiment, then count
sentiment_trend = df.groupby(['year', 'sentiment']).size().reset_index(name='count')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.lineplot(data=sentiment_trend, x='year', y='count', hue='sentiment', marker='o')
plt.title("Sentiment Trend Over the Years")
plt.xlabel("Year")
plt.ylabel("Number of Comments")
plt.grid(True)
plt.show()

# %%
df['month'] = df['date'].dt.to_period('M').astype(str)
monthly_trend = df.groupby(['month', 'sentiment']).size().reset_index(name='count')

plt.figure(figsize=(14, 6))
sns.lineplot(data=monthly_trend, x='month', y='count', hue='sentiment', marker='o')
plt.title("Monthly Sentiment Trend")
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6228\2731225207.py:1: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['month'] = df['date'].dt.to_period('M').astype(str)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(x='sentiment', y='likesCount', data=df, palette='Set2')
plt.title('Likes by Sentiment')
plt.ylabel('Likes')
plt.xlabel('Sentiment')
plt.grid(True)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6228\2813226570.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='sentiment', y='likesCount', data=df, palette='Set2')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='sentiment', y='commentsCount', data=df, palette='pastel')
plt.title('Replies by Sentiment')
plt.ylabel('Number of Replies')
plt.xlabel('Sentiment')
plt.grid(True)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6228\3906028285.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='sentiment', y='commentsCount', data=df, palette='pastel')

# %%
df.groupby('sentiment')[['likesCount', 'commentsCount']].mean().round(2)
# Out:
#            likesCount  commentsCount
# sentiment
# Negative         5.58          10.89
# Neutral          2.29           6.88
# Positive         7.00           9.15

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 from wordcloud import WordCloud, STOPWORDS
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
pip install wordcloud
# Out:
# ...
#    ---------------------------------------- 0.0/299.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/299.9 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/299.9 kB 487.6 kB/s eta 0:00:01
#    ---------------- ----------------------- 122.9/299.9 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  297.0/299.9 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 299.9/299.9 kB 1.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
positive_text = " ".join(df[df['sentiment'] == 'Positive']['text'].dropna().astype(str))

wordcloud_pos = WordCloud(width=800, height=400, background_color='white',
                          stopwords=STOPWORDS).generate(positive_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud - Positive Comments")
plt.show()

# %%
negative_text = " ".join(df[df['sentiment'] == 'Negative']['text'].dropna().astype(str))

wordcloud_neg = WordCloud(width=800, height=400, background_color='black',
                          stopwords=STOPWORDS, colormap='Reds').generate(negative_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud - Negative Comments", color='white')
plt.show()

# %%
neutral_text = " ".join(df[df['sentiment'] == 'Neutral']['text'].dropna().astype(str))

wordcloud_neu = WordCloud(width=800, height=400, background_color='lightgray',
                          stopwords=STOPWORDS, colormap='Greens').generate(neutral_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_neu, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud - Neutral Comments")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
X = df['text'].astype(str)           # Text comments
y = df['sentiment']                  # Labels (Positive, Negative, Neutral)

# %%
tfidf = TfidfVectorizer(max_features=3000, stop_words='english')
X_tfidf = tfidf.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf, y, test_size=0.2, random_state=42, stratify=y)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=model.classes_, yticklabels=model.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00        18
#      Neutral       0.57      0.87      0.68        45
#     Positive       0.72      0.62      0.67        42
#
#     accuracy                           0.62       105
#    macro avg       0.43      0.50      0.45       105
# weighted avg       0.53      0.62      0.56       105
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
# !pip install joblib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import joblib

# Save TF-IDF vectorizer
joblib.dump(tfidf, 'vectorizer.pkl')

# Save trained classification model
joblib.dump(model, 'sentiment_model.pkl')
# Out:
# ['sentiment_model.pkl']
